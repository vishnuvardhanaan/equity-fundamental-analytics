# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt

# %%
conn1 = sqlite3.connect(r"E:\Dev_Environment\equity-fundamental-analytics\data\silver\nse_equity_universe_silver.db")
conn2 = sqlite3.connect(r"E:\Dev_Environment\equity-fundamental-analytics\data\gold\nse_equity_universe_gold.db")

# %%
with open(r"E:\Dev_Environment\equity-fundamental-analytics\src\gold\sql\gold_equity_basemetrics.sql") as f:
    query = f.read()

df_ebm = pd.read_sql(query, conn1)

# %%
# df_ebm = df_ebm.fillna("")

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df_ebm.isna(), cbar=True,)
plt.title("Missing Values Heatmap")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# %%
df_ebm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2084 entries, 0 to 2083
# Data columns (total 71 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   symbol                                            2084 non-null   object
#  1   latest_fiscal_year                                2064 non-null   float64
#  2   company_name                                      2084 non-null   object
#  3   city                                              2082 non-null   object
#  4   sector                                            2082 non-null   object
#  5   industry                                          2082 non-null   object
#  6   long_business_summary                             2082 non-null   object
#  7   current_price                                     2083 non-null   float64
#  8   shares_outstanding                                2070 non-null   float64
# ...

# %%
# df.to_sql("gold_equity_basemetrics", conn2, if_exists="replace", index=False)
